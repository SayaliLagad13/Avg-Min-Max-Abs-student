# %%
def avg():
    cnt=0
    sum=0
    for j in range(len(mark)):
        if mark[j]== -1:
            cnt+=1
    for i in range(len(mark)):
        if(mark[i]!=-1):
            sum+=mark[i]
    print("average of marks is:",sum/(len(mark)-cnt))

def min():
    min=mark[0]
    for k in mark:
        if(k!= -1 and k<min):
            min=k
    print("minimum mark is:",min)

def max():
    max=mark[0]
    for j in mark:
        if(j!= -1 and j>max):
            max=j
    print("maximum mark is:",max)

def abs():
    abscnt=0
    for i in mark:
        if i== -1:
            abscnt+=1
    print("absent count is:",abscnt)

def freq():
    i=0
    max=0
    num=mark[0]
    for i in mark:
        cur_fre=mark.count(i)
        if cur_fre>max:
            max=cur_fre
            num=i
            print(num,max)    

mark=[]
n=int(input("enter how many students :"))
print("\n enter marks and -1 for absent student:")
for i in range(0,n):
    ele=int(input(""))
    mark.append(ele)
avg()
min()
max()
abs()
freq()
# Out:
# enter how many students :5
#
#  enter marks and -1 for absent student:
# 28
# 21
# 18
# -1
# 12
# average of marks is: 19.75
# minimum mark is: 12
# maximum mark is: 28
# absent count is: 1
# 28 1

# %%
def avg():
    cnt=0
    sum=0
for j in range(len(mark)):
    if mark[j]==-1:
        cnt+=1
for i in range(len(mark)):
    if(mark[i]!=-1):
        sum+=mark[0]
print("Average Score is:",sum/(len(mark)-cnt))

def min():
    min=mark[0]
for k in mark:
    if(k!=-1 and k<min):
        min=k
print("Minimum Score is:",min)

def max():
    max=mark[0]
for j in mark:
    if(j!=-1 and j>max):
        max=j
print("Maxmium Score is:",max)

def abscnt():
    abscnt=0
for i in mark:
    if i==-1:
        abscnt+=1
print("Abscent count is:",abscnt)

def freq():
    i=0
    max=0
    num=mark[0]
for i in mark:
    cur_fre=mark.count(i)
    if cur_fre>max:
        cur_fre=max
        num=i
print("num,max",num,max)

mark=[]
n=int(input("Enter How Many Student:"))
print("Enter the Mark and -1 for Abscent student:")
ele=int(input(" "))
mark.append(ele)
avg()
min()
max()
abs()
freq()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8048\3736206248.py in <module>
#       4 for j in range(len(mark)):
#       5     if mark[j]==-1:
# ----> 6         cnt+=1
#       7 for i in range(len(mark)):
#       8     if(mark[i]!=-1):
#
# NameError: name 'cnt' is not defined
